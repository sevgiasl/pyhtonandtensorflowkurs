# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1=np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2=numpyDizisi1**2

# %%
(benimFİgur,benimEksen)=plt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2,color="#3A95A8",alpha=0.3) #alpha,transparanlık
benimEksen.plot(numpyDizisi2,numpyDizisi1,"b")
#rgb hex code ,renklerin kodları için google

# %%
(yeniFigur,yeniEksen)=plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1+2,color="b",linewidth=8.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1+3,color="y",linewidth=6.0)

yeniEksen.plot(numpyDizisi1,numpyDizisi1+4,color="#C96F23",linestyle="--")
yeniEksen.plot(numpyDizisi1,numpyDizisi1+5,color="#C96F23",linestyle=":")
yeniEksen.plot(numpyDizisi1,numpyDizisi1+6,color="#C96F23",linestyle="-.")

yeniEksen.plot(numpyDizisi1,numpyDizisi1+7,color="#000000",linestyle="--",marker="o",markersize=8,markerfacecolor="r")
yeniEksen.plot(numpyDizisi1,numpyDizisi1+8,color="#000000",linestyle="--",marker="+",markersize=12)

# %% [markdown]
# ## scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# ## histogram

# %%
yeniDizi=np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([ 5, 42, 72, 32, 43,  1, 17, 42, 38, 61,  7, 43, 57, 75, 99,  8, 69,
#        17, 31, 96, 40, 57, 14, 36, 81, 38, 79, 61, 65, 25, 71, 71, 83, 76,
#        32, 22, 24, 98,  6,  0, 17, 27, 52, 94, 80, 30, 50, 18, 68, 44])

# %%
plt.hist(yeniDizi)
# Out:
# (array([6., 5., 4., 7., 6., 4., 5., 6., 3., 4.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x273aeae0e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x273aeae2050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x273ae7906d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x273aeae3110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x273ae80b8d0>],
#  'means': []}
