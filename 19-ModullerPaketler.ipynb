# %%
import numpy as np
import matplotlib.pyplot as matplot

# %%
maasListesi=np.random.normal(4000,500,1000)
#4000 lira civarında 500 standart sapmalı 100 tane veri oluştur
np.mean(maasListesi)#ortalamasını al
# Out:
# 4007.7588054655776

# %%
matplot.hist(maasListesi,50)
matplot.show()
